# %% [markdown]
# # ARC Fuel Cycle Single vs Parallel BCR TES Shutdown Event Comparison
#
# This notebook loads the `arc_single_bcr_shutdown.pvm` and `arc_parallel_bcr_shutdown.pvm` PathView models from the `/pathview_graphs/` directory, runs both simulations using parallel workers, and saves the results to the `/results/` directory. It then plots the scope outputs and saves these to the `/plots/` directory.
#
# Both the single and parallel BCR models use a 3 meter tall reactor design, with the parallel model splitting the liquid and gas flows equally between two identical parallel reactors.
#
# At `t = 1 * 24 * 3600s`, a shutdown event is triggered, simulating one reactor shutting down and its tritium extraction ceasing.
# With the single BCR, this causes tritium extraction from the breeder to stop entirely. For the parallel BCRs, the total liquid & gas flows are routed through the remaining online reactor, allowing tritium extraction to continue.
#
# At `t = 2 * 24 * 3600s` the shutdown ends and the systems revert to normal operation.

# %%
# Load the models and create pathsim simulations

# Run the simulations using parallel workers

# Save the results as npz files

# Plot the results
    # - Inventories

# Save the plots
