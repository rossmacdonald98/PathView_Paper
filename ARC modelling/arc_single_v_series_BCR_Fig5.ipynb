# %% [markdown]
# # ARC Fuel Cycle Single vs Series BCR Efficiency Comparison
#
# This notebook loads the `arc_single_bcr.pvm` and `arc_series_bcrs.pvm` PathView models from the `/pathview_graphs/` directory, runs both simulations using parallel workers, and saves the results to the `/results/` directory. It then plots the scope outputs and saves these to the `/plots/` directory.
#
# The single BCR model uses a single 3 meter tall reactor, while the series BCR model uses a series of 3 x 1 meter tall reactors.

# %%
# Load the models and create pathsim simulations

# Run the simulations using parallel workers

# Save the results as npz files

# Plot the results

    # - extraction efficiencies (each BCR & total)

# Save the plots
