# %% [markdown]
# # Python-executable version of PathView Graphs for ARC single BCR & parallel BCRs with shutdown event models
#
# Runs two ARC-class fuel cycle residence time models:
#  1) with a single 3m high BCR as the TES, and the BCR shutting down between days 2-3.
#  2) with 2 x 3m high BCRs in parallel as the TES, with one BCR shutting down between days 2-3.
#
# Expect script to take around 60 minutes to run.
#
# If both results files already present, can skip to funning only plotting cell.

# %%
from pathview_python_code import arc_single_bcr_shutdown

# Execute the function to run the model and save results
arc_single_bcr_shutdown(10 * 24 * 3600) # 10 days in seconds
# Out:
# 15:03:31 - INFO - LOGGING (log: True)
# 15:03:31 - INFO - BLOCKS (total: 41, dynamic: 10, static: 31, eventful: 1)
# 15:03:31 - INFO - GRAPH (nodes: 41, edges: 61, alg. depth: 7, loop depth: 0, runtime: 1.074ms)
# 15:03:31 - INFO - STARTING -> TRANSIENT (Duration: 864000.00s)
# c_T_in:  0.0001237010781998846
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.0001237010781998846
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.0001237010781998846
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.00012370096824337065
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.00012370091447316464
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.00012370075316254055
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.00012370054184009026
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.00012370060741694674
# y_T2_in : 0.0
# flow_l:  560.0
# flow_g:  0.19
# c_T_in:  0.00012370054184008457
# y_T2_in : 0.0
# ...

# %%
from pathview_python_code import arc_parallel_bcrs_shutdown

# Execute the function to run the model and save results
arc_parallel_bcrs_shutdown(10 * 24 * 3600) # 10 days in seconds
